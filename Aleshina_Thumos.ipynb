# %% [markdown]
# <h1>Table of Contents<span class="tocSkip"></span></h1>
# <div class="toc"><ul class="toc-item"><li><span><a href="#Test-case-№1:" data-toc-modified-id="Test-case-№1:-1">Test case №1:</a></span></li><li><span><a href="#Test-case-№2:" data-toc-modified-id="Test-case-№2:-2">Test case №2:</a></span><ul class="toc-item"><li><span><a href="#Data-Exploration" data-toc-modified-id="Data-Exploration-2.1">Data Exploration</a></span></li><li><span><a href="#Cleaning-the-Data" data-toc-modified-id="Cleaning-the-Data-2.2">Cleaning the Data</a></span></li><li><span><a href="#Feature-Analysis" data-toc-modified-id="Feature-Analysis-2.3">Feature Analysis</a></span></li><li><span><a href="#Feature-Engineering" data-toc-modified-id="Feature-Engineering-2.4">Feature Engineering</a></span></li><li><span><a href="#Final-assessment" data-toc-modified-id="Final-assessment-2.5">Final assessment</a></span></li></ul></li></ul></div>

# %% [markdown]
# ## Test case №1:
# <div class="alert alert-info">
#     We extracted data from GCP. The dataset contains 4 million rows, but we were only able to extract them in small portions, about 40,000 rows in CSV format. In total, we ended up with 110 files. The files are named as follows:
#
# data_000000000001.csv
# data_000000000002.csv
# …..
# data_000000000010.csv
# data_000000000011.csv
# ……
# data_000000000100.csv
# data_000000000101.csv
# ….
# data_000000000110.csv
#
# Please suggest a method for uploading all these 110 files using Jupyter Notebook (or another) and merging them into a single dataset for further processing.
#     </div>

# %%
import pandas as pd
import glob

# get the list of file paths using glob module
file_paths = glob.glob("path/to/files/data_*.csv")

# initialize an empty DataFrame to store the merged data
all_data = pd.DataFrame()

# loop through each file and concatenate data
for file_path in file_paths:
    df = pd.read_csv(file_path)
    all_data = pd.concat([all_data, df], ignore_index=True)

# check the first few rows of the merged data
print(all_data.head())
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %% [markdown]
# ## Test case №2:
# <div class="alert alert-info">
#     You can find the file in this folder, which contains Linkedin profile scrapes of individuals that were part of an outreach effort. The goal is to get people to purchase a ticket to an event and ultimately join the organization as a member.  Since the same method of profile scraping will be used in the future to identify the best leads, it's important that patterns that exist in the content of the profiles be identified.
#
# The column 'Result' has one of six outcomes for each person:
# - **Purchased membership**: The ideal outcome, bought an event ticket and a membership
# - **Purchased event**: A positive outcome but not ideal
# - Approved: They were approved to come to an event but did not purchase
# - Sent personal f/u: Conversation was started but ended
# - Out of sequence: Conversation was started but ended
# - 2021 Member: Someone who was a previous member of the organization
#
# In order to better focus outreach efforts in the future, we need to determine which characteristics show a higher probability of purchasing a membership and/or purchasing an event ticket.
#
# Please provide an analysis that identifies what traits, characteristics, patterns, etc. can be used to indicate a higher probability of a positive/ideal outcome and please describe your methodology.
# </div>

# %% [markdown]
# ### Data Exploration

# %% [markdown]
# In this section we will generally study the provided data: their number, the presence of duplicates, the number of omissions in the data. We will evaluate the distribution of users by the final result (taking or not taking a target action).

# %%
# load the necessary libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.preprocessing import LabelEncoder
import re

pd.set_option('display.max_columns', 1000)

# %%
# check the basic info abouth the dataset
linkedin_data = pd.read_csv('Linkedin_Accounts.csv')
linkedin_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 348 entries, 0 to 347
# Data columns (total 74 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   linkedinProfile               348 non-null    object
#  1   Result                        348 non-null    object
#  2   Other                         191 non-null    object
#  3   email                         216 non-null    object
#  4   description                   279 non-null    object
#  5   headline                      347 non-null    object
#  6   location                      348 non-null    object
#  7   firstName                     348 non-null    object
#  8   lastName                      348 non-null    object
#  9   fullName                      348 non-null    object
#  10  subscribers                   347 non-null    float64
#  11  userId                        289 non-null    float64
#  12  mutualConnectionsText         4 non-null      object
#  13  mailFromDropcontact           154 non-null    object
#  14  company                       346 non-null    object
#  15  companyUrl                    263 non-null    object
#  16  jobTitle                      347 non-null    object
#  17  jobDescription                172 non-null    object
#  18  jobLocation                   215 non-null    object
#  19  jobDateRange                  342 non-null    object
#  20  company2                      335 non-null    object
#  21  companyUrl2                   236 non-null    object
#  22  jobTitle2                     335 non-null    object
#  23  jobDescription2               186 non-null    object
#  24  jobDateRange2                 332 non-null    object
#  25  school                        328 non-null    object
#  26  schoolUrl                     275 non-null    object
#  27  schoolDegree                  267 non-null    object
#  28  schoolDegreeSpec              227 non-null    object
#  29  schoolDateRange               287 non-null    object
#  30  school2                       208 non-null    object
#  31  schoolUrl2                    164 non-null    object
#  32  schoolDegree2                 156 non-null    object
#  33  schoolDegreeSpec2             144 non-null    object
#  34  schoolDateRange2              177 non-null    object
#  35  qualificationFromDropContact  154 non-null    object
#  36  civilityFromDropContact       277 non-null    object
#  37  phoneNumberFromDropContact    104 non-null    object
#  38  websiteFromDropContact        323 non-null    object
#  39  twitter                       142 non-null    object
#  40  website                       205 non-null    object
#  41  companyWebsite                247 non-null    object
#  42  allSkills                     330 non-null    object
#  43  skill1                        330 non-null    object
#  44  endorsement1                  329 non-null    object
#  45  skill2                        330 non-null    object
#  46  endorsement2                  329 non-null    object
#  47  skill3                        330 non-null    object
#  48  endorsement3                  329 non-null    object
#  49  skill4                        330 non-null    object
#  50  endorsement4                  329 non-null    object
#  51  skill5                        329 non-null    object
#  52  endorsement5                  329 non-null    object
#  53  skill6                        326 non-null    object
#  54  endorsement6                  326 non-null    object
#  55  baseUrl                       348 non-null    object
#  56  profileId                     348 non-null    object
#  57  timestamp                     348 non-null    object
#  58  jobLocation2                  246 non-null    object
#  59  connectionsCount              50 non-null     float64
#  60  mail                          3 non-null      object
#  61  birthday                      95 non-null     object
#  62  schoolDescription2            44 non-null     object
#  63  naf5CodeFromDropContact       16 non-null     object
#  64  naf5DesFromDropContact        14 non-null     object
#  65  sirenFromDropContact          16 non-null     float64
#  66  siretFromDropContact          16 non-null     float64
#  67  siretAddressFromDropContact   15 non-null     object
#  68  siretZipFromDropContact       15 non-null     float64
#  69  vatFromDropContact            16 non-null     object
#  70  schoolDescription             65 non-null     object
#  71  nbEmployeesFromDropContact    12 non-null     object
#  72  Unnamed: 72                   0 non-null      float64
#  73  Unnamed: 73                   62 non-null     object
# dtypes: float64(7), object(67)
# memory usage: 201.3+ KB

# %%
linkedin_data = linkedin_data.drop_duplicates()
len(linkedin_data)
# Out:
# 348

# %% [markdown]
# No duplicates were found in the data. Let's study the distribution of the number of users among the main categories by final actions.

# %%
plt.figure(figsize=(15, 6))
plt.hist(linkedin_data['Result']);

# %%
print(f"Total Purchased Membership: {len(linkedin_data[linkedin_data['Result'] == '5. Purchased Membership'])}")
print(f"Total Purchased Event: {len(linkedin_data[linkedin_data['Result'] == '4.Purchased Event'])}")
# Out:
# Total Purchased Membership: 4
# Total Purchased Event: 6

# %% [markdown]
# Only 10 users took the targeted action.

# %% [markdown]
# ### Cleaning the Data
#
# Since there are many omissions in the data, we will remove those columns with more than 50% of the data missing.

# %%
pd.DataFrame(round((linkedin_data.isna().mean()*100))).style.background_gradient('coolwarm')
# Out:
# <style type="text/css">
# #T_3ffcb_row0_col0, #T_3ffcb_row1_col0, #T_3ffcb_row5_col0, #T_3ffcb_row6_col0, #T_3ffcb_row7_col0, #T_3ffcb_row8_col0, #T_3ffcb_row9_col0, #T_3ffcb_row10_col0, #T_3ffcb_row16_col0, #T_3ffcb_row55_col0, #T_3ffcb_row56_col0, #T_3ffcb_row57_col0 {
#   background-color: #3b4cc0;
#   color: #f1f1f1;
# }
# #T_3ffcb_row2_col0 {
#   background-color: #cfdaea;
#   color: #000000;
# }
# #T_3ffcb_row3_col0, #T_3ffcb_row18_col0 {
#   background-color: #bad0f8;
#   color: #000000;
# }
# #T_3ffcb_row4_col0, #T_3ffcb_row36_col0 {
#   background-color: #7b9ff9;
#   color: #f1f1f1;
# }
# #T_3ffcb_row11_col0 {
#   background-color: #7093f3;
#   color: #f1f1f1;
# }
# #T_3ffcb_row12_col0, #T_3ffcb_row60_col0 {
#   background-color: #b70d28;
#   color: #f1f1f1;
# }
# #T_3ffcb_row13_col0, #T_3ffcb_row35_col0 {
#   background-color: #ebd3c6;
#   color: #000000;
# }
# #T_3ffcb_row14_col0 {
#   background-color: #3d50c3;
#   color: #f1f1f1;
# }
# #T_3ffcb_row15_col0 {
#   background-color: #89acfd;
#   color: #000000;
# }
# #T_3ffcb_row17_col0 {
#   background-color: #dfdbd9;
#   color: #000000;
# }
# #T_3ffcb_row19_col0 {
#   background-color: #4055c8;
#   color: #f1f1f1;
# }
# #T_3ffcb_row20_col0, #T_3ffcb_row22_col0 {
#   background-color: #465ecf;
#   color: #f1f1f1;
# }
# #T_3ffcb_row21_col0 {
#   background-color: #a5c3fe;
#   color: #000000;
# }
# #T_3ffcb_row23_col0 {
#   background-color: #d5dbe5;
#   color: #000000;
# }
# #T_3ffcb_row24_col0, #T_3ffcb_row42_col0, #T_3ffcb_row43_col0, #T_3ffcb_row44_col0, #T_3ffcb_row45_col0, #T_3ffcb_row46_col0, #T_3ffcb_row47_col0, #T_3ffcb_row48_col0, #T_3ffcb_row49_col0, #T_3ffcb_row50_col0, #T_3ffcb_row51_col0, #T_3ffcb_row52_col0 {
#   background-color: #4961d2;
#   color: #f1f1f1;
# }
# #T_3ffcb_row25_col0, #T_3ffcb_row53_col0, #T_3ffcb_row54_col0 {
#   background-color: #4c66d6;
#   color: #f1f1f1;
# }
# #T_3ffcb_row26_col0 {
#   background-color: #7ea1fa;
#   color: #f1f1f1;
# }
# #T_3ffcb_row27_col0 {
#   background-color: #85a8fc;
#   color: #f1f1f1;
# }
# #T_3ffcb_row28_col0 {
#   background-color: #afcafc;
#   color: #000000;
# }
# #T_3ffcb_row29_col0 {
#   background-color: #7597f6;
#   color: #f1f1f1;
# }
# #T_3ffcb_row30_col0 {
#   background-color: #c0d4f5;
#   color: #000000;
# }
# #T_3ffcb_row31_col0 {
#   background-color: #e4d9d2;
#   color: #000000;
# }
# #T_3ffcb_row32_col0 {
#   background-color: #e9d5cb;
#   color: #000000;
# }
# #T_3ffcb_row33_col0, #T_3ffcb_row39_col0 {
#   background-color: #f1cdba;
#   color: #000000;
# }
# #T_3ffcb_row34_col0 {
#   background-color: #dadce0;
#   color: #000000;
# }
# #T_3ffcb_row37_col0 {
#   background-color: #f7ac8e;
#   color: #000000;
# }
# #T_3ffcb_row38_col0 {
#   background-color: #4f69d9;
#   color: #f1f1f1;
# }
# #T_3ffcb_row40_col0 {
#   background-color: #c3d5f4;
#   color: #000000;
# }
# #T_3ffcb_row41_col0, #T_3ffcb_row58_col0 {
#   background-color: #9bbcff;
#   color: #000000;
# }
# #T_3ffcb_row59_col0 {
#   background-color: #e16751;
#   color: #f1f1f1;
# }
# #T_3ffcb_row61_col0 {
#   background-color: #f6a283;
#   color: #000000;
# }
# #T_3ffcb_row62_col0 {
#   background-color: #df634e;
#   color: #f1f1f1;
# }
# #T_3ffcb_row63_col0, #T_3ffcb_row65_col0, #T_3ffcb_row66_col0, #T_3ffcb_row69_col0 {
#   background-color: #c53334;
#   color: #f1f1f1;
# }
# #T_3ffcb_row64_col0, #T_3ffcb_row67_col0, #T_3ffcb_row68_col0 {
#   background-color: #c32e31;
#   color: #f1f1f1;
# }
# #T_3ffcb_row70_col0 {
#   background-color: #ec7f63;
#   color: #f1f1f1;
# }
# #T_3ffcb_row71_col0 {
#   background-color: #be242e;
#   color: #f1f1f1;
# }
# #T_3ffcb_row72_col0 {
#   background-color: #b40426;
#   color: #f1f1f1;
# }
# #T_3ffcb_row73_col0 {
#   background-color: #ea7b60;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_3ffcb">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_3ffcb_level0_col0" class="col_heading level0 col0" >0</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_3ffcb_level0_row0" class="row_heading level0 row0" >linkedinProfile</th>
#       <td id="T_3ffcb_row0_col0" class="data row0 col0" >0.000000</td>
#     </tr>
#     <tr>
#       <th id="T_3ffcb_level0_row1" class="row_heading level0 row1" >Result</th>
#       <td id="T_3ffcb_row1_col0" class="data row1 col0" >0.000000</td>
#     </tr>
#     <tr>
#       <th id="T_3ffcb_level0_row2" class="row_heading level0 row2" >Other</th>
#       <td id="T_3ffcb_row2_col0" class="data row2 col0" >45.000000</td>
#     </tr>
#     <tr>
#       <th id="T_3ffcb_level0_row3" class="row_heading level0 row3" >email</th>
#       <td id="T_3ffcb_row3_col0" class="data row3 col0" >38.000000</td>
#     </tr>
#     <tr>
#       <th id="T_3ffcb_level0_row4" class="row_heading level0 row4" >description</th>
#       <td id="T_3ffcb_row4_col0" class="data row4 col0" >20.000000</td>
#     </tr>
#     <tr>
#       <th id="T_3ffcb_level0_row5" class="row_heading level0 row5" >headline</th>
#       <td id="T_3ffcb_row5_col0" class="data row5 col0" >0.000000</td>
#     </tr>
#     <tr>
#       <th id="T_3ffcb_level0_row6" class="row_heading level0 row6" >location</th>
#       <td id="T_3ffcb_row6_col0" class="data row6 col0" >0.000000</td>
#     </tr>
#     <tr>
#       <th id="T_3ffcb_level0_row7" class="row_heading level0 row7" >firstName</th>
#       <td id="T_3ffcb_row7_col0" class="data row7 col0" >0.000000</td>
#     </tr>
#     <tr>
#       <th id="T_3ffcb_level0_row8" class="row_heading level0 row8" >lastName</th>
#       <td id="T_3ffcb_row8_col0" class="data row8 col0" >0.000000</td>
#     </tr>
#     <tr>
#       <th id="T_3ffcb_level0_row9" class="row_heading level0 row9" >fullName</th>
#       <td id="T_3ffcb_row9_col0" class="data row9 col0" >0.000000</td>
#     </tr>
#     <tr>
#       <th id="T_3ffcb_level0_row10" class="row_heading level0 row10" >subscribers</th>
#       <td id="T_3ffcb_row10_col0" class="data row10 col0" >0.000000</td>
#     </tr>
#     <tr>
#       <th id="T_3ffcb_level0_row11" class="row_heading level0 row11" >userId</th>
#       <td id="T_3ffcb_row11_col0" class="data row11 col0" >17.000000</td>
#     </tr>
#     <tr>
#       <th id="T_3ffcb_level0_row12" class="row_heading level0 row12" >mutualConnectionsText</th>
#       <td id="T_3ffcb_row12_col0" class="data row12 col0" >99.000000</td>
#     </tr>
#     <tr>
#       <th id="T_3ffcb_level0_row13" class="row_heading level0 row13" >mailFromDropcontact</th>
#       <td id="T_3ffcb_row13_col0" class="data row13 col0" >56.000000</td>
#     </tr>
#     <tr>
#       <th id="T_3ffcb_level0_row14" class="row_heading level0 row14" >company</th>
#       <td id="T_3ffcb_row14_col0" class="data row14 col0" >1.000000</td>
#     </tr>
#     <tr>
#       <th id="T_3ffcb_level0_row15" class="row_heading level0 row15" >companyUrl</th>
#       <td id="T_3ffcb_row15_col0" class="data row15 col0" >24.000000</td>
#     </tr>
#     <tr>
#       <th id="T_3ffcb_level0_row16" class="row_heading level0 row16" >jobTitle</th>
#       <td id="T_3ffcb_row16_col0" class="data row16 col0" >0.000000</td>
#     </tr>
#     <tr>
#       <th id="T_3ffcb_level0_row17" class="row_heading level0 row17" >jobDescription</th>
#       <td id="T_3ffcb_row17_col0" class="data row17 col0" >51.000000</td>
#     </tr>
#     <tr>
#       <th id="T_3ffcb_level0_row18" class="row_heading level0 row18" >jobLocation</th>
#       <td id="T_3ffcb_row18_col0" class="data row18 col0" >38.000000</td>
#     </tr>
#     <tr>
#       <th id="T_3ffcb_level0_row19" class="row_heading level0 row19" >jobDateRange</th>
#       <td id="T_3ffcb_row19_col0" class="data row19 col0" >2.000000</td>
#     </tr>
#     <tr>
#       <th id="T_3ffcb_level0_row20" class="row_heading level0 row20" >company2</th>
#       <td id="T_3ffcb_row20_col0" class="data row20 col0" >4.000000</td>
#     </tr>
#     <tr>
#       <th id="T_3ffcb_level0_row21" class="row_heading level0 row21" >companyUrl2</th>
#       <td id="T_3ffcb_row21_col0" class="data row21 col0" >32.000000</td>
#     </tr>
#     <tr>
#       <th id="T_3ffcb_level0_row22" class="row_heading level0 row22" >jobTitle2</th>
#       <td id="T_3ffcb_row22_col0" class="data row22 col0" >4.000000</td>
#     </tr>
#     <tr>
#       <th id="T_3ffcb_level0_row23" class="row_heading level0 row23" >jobDescription2</th>
#       <td id="T_3ffcb_row23_col0" class="data row23 col0" >47.000000</td>
#     </tr>
#     <tr>
#       <th id="T_3ffcb_level0_row24" class="row_heading level0 row24" >jobDat

# %%
# threshold for removing columns with gaps
threshold = len(linkedin_data) * 0.5

# delete columns where the number of gaps is greater than 50%
linkedin_data = linkedin_data.dropna(thresh=threshold, axis=1)

# %% [markdown]
# Still quite a few columns to "manually" analyze. Let's look at the columns, maybe some of the data is of little value or can be merged or interchanged.

# %%
linkedin_data.head()
# Out:
#                                      linkedinProfile                   Result  \
# 0    https://www.linkedin.com/in/mark-kohoot-96a08b1  5. Purchased Membership
# 1            https://www.linkedin.com/in/jonbowerman  5. Purchased Membership
# 2           https://www.linkedin.com/in/parkeralynch  5. Purchased Membership
# 3          https://www.linkedin.com/in/shacharschiff  5. Purchased Membership
# 4  https://www.linkedin.com/in/gary-lacourt-811b1874        4.Purchased Event
#
#     Other                              email  \
# 0  Hunter                   mk@aeroscena.com
# 1  Hunter                   jon@kidsdraw.org
# 2  Hunter          Parker@HedgeHogHealth.com
# 3  Hunter             shachar@badtesting.com
# 4  Hunter  gary.lacourt@forevercompanies.com
#
#                                          description  \
# 0  Mark founded Aeroscena in 2010 with the missio...
# 1  A creative problem solver who can rapidly desi...
# 2                                             #NAME?
# 3  I'm the founder and principal consultant at Ba...
# 4  Serial entrepreneur and business founder. Main...
#
#                                             headline  \
# 0          Bio-pharmaceutical / functional fragrance
# 1  Co Founder and CTO - Product Development and M...
# 2  CEO at HedgeHog Health | 2020-2021 Global Educ...
# 3  I believe that high-quality, powerful software...
# 4                 Founder and CEO, Forever Companies
#
#                               location firstName  lastName        fullName  \
# 0       Cleveland, Ohio, United States      Mark    Kohoot     Mark Kohoot
# 1  Farmington, Michigan, United States       Jon  Bowerman    Jon Bowerman
# 2   Royal Oak, Michigan, United States    Parker     Lynch    Parker Lynch
# 3          Dallas-Fort Worth Metroplex   Shachar    Schiff  Shachar Schiff
# 4  Milwaukee, Wisconsin, United States      Gary   LaCourt    Gary LaCourt
#
#    subscribers       userId                                     company  \
# 0       1704.0    3172258.0                                   Aeroscena
# 1       1745.0   14910006.0                               Kids Draw Bob
# 2       2549.0   22364061.0                             HedgeHog Health
# 3       1696.0   35484653.0  BadTestingÂ® â€” Better Software. On Time.
# 4        710.0  265539469.0                           Forever Companies
#
#                                           companyUrl  \
# 0        https://www.linkedin.com/company/aeroscena/
# 1      https://www.linkedin.com/company/kidsdrawbob/
# 2   https://www.linkedin.com/company/hedgehoghealth/
# 3       https://www.linkedin.com/company/badtesting/
# 4  https://www.linkedin.com/company/forever-compa...
#
#                     jobTitle                   jobLocation  \
# 0                        CEO    Cleveland/Akron, Ohio Area
# 1  President and Illustrator          Bloomfield Hills, MI
# 2    Chief Executive Officer                           NaN
# 3      Founder and Principal  Austin, Texas, United States
# 4              Founder & CEO        Greater Milwaukee Area
#
#            jobDateRange                                     company2  \
# 0  Sep 2010 â€“ Present          Cleveland Clinic Wellness Institute
# 1  Jul 2019 â€“ Present                    High Level Marketing, LLC
# 2  Nov 2019 â€“ Present           Born and Raised Detroit Foundation
# 3  Mar 2012 â€“ Present                             The Webby Awards
# 4  Aug 2004 â€“ Present  Milwaukee Business Journal Leadership Trust
#
#                                          companyUrl2  \
# 0  https://www.linkedin.com/company/cleveland-cli...
# 1  https://www.linkedin.com/company/high-level-ma...
# 2  https://www.linkedin.com/company/born-and-rais...
# 3  https://www.linkedin.com/company/the-webby-awa...
# 4  https://www.linkedin.com/company/milwaukee-bus...
#
#                                         jobTitle2  \
# 0                         Advisor to the Chairman
# 1  Co Founder and CTO - VP of Product Development
# 2                              Executive Director
# 3                                 Associate Judge
# 4                                  Charter Member
#
#                                      jobDescription2         jobDateRange2  \
# 0  Supporting the Chairman of the Wellness Instit...         2009 â€“ 2010
# 1  As one of the fastest growing online marketing...  Nov 2009 â€“ Present
# 2  â€¢Organize events in cities from coast to coa...  Jan 2016 â€“ Present
# 3  The Webby Awards is the leading international ...  Feb 2015 â€“ Present
# 4                                                NaN  Jun 2019 â€“ Present
#
#                                 school  \
# 0  Audencia Nantes Ecole de Management
# 1               University of Michigan
# 2                  New York University
# 3                     DeVry University
# 4              Northwestern University
#
#                                            schoolUrl  \
# 0  https://www.linkedin.com/school/19998/?legacyS...
# 1  https://www.linkedin.com/school/18633/?legacyS...
# 2  https://www.linkedin.com/school/18993/?legacyS...
# 3  https://www.linkedin.com/school/21203/?legacyS...
# 4  https://www.linkedin.com/school/18290/?legacyS...
#
#                  schoolDegree                        schoolDegreeSpec  \
# 0                      master                               marketing
# 1  Bachelor of Science (B.S.)                            Architecture
# 2                     Dual MA  Childhood Education, Special Education
# 3    Bachelor of Science - BS  Electrical and Electronics Engineering
# 4                         NaN                                     NaN
#
#   schoolDateRange                            school2 schoolDateRange2  \
# 0   1984 â€“ 1985          The Ohio State University    1979 â€“ 1983
# 1   1999 â€“ 2004    Walled Lake Central High School    1995 â€“ 1999
# 2   2011 â€“ 2013     Indiana University Bloomington    2002 â€“ 2006
# 3   1997 â€“ 2000                                NaN              NaN
# 4             NaN  University of Wisconsin-Milwaukee              NaN
#
#   civilityFromDropContact    websiteFromDropContact  \
# 0                      Mr         www.aeroscena.com
# 1                      Mr          www.kidsdraw.org
# 2                      Mr    www.hedgehoghealth.com
# 3                      Mr        www.badtesting.com
# 4                      Mr  www.forevercompanies.com
#
#                           website                  companyWebsite  \
# 0  stumbleupon.com/content/1LSMVB           https://aeroscena.com
# 1                             NaN  http://www.kidsdraw.org/donate
# 2       bornandraiseddetroit.org/   http://www.hedgehoghealth.com
# 3                  badtesting.com       http://www.badtesting.com
# 4           forevercompanies.com/     http://forevercompanies.com
#
#                                            allSkills  \
# 0  Strategic Planning, Leadership, Marketing Stra...
# 1  Web Design, Marketing, Business Strategy, SEO,...
# 2  Editing, Blogging, Social Media, Event Plannin...
# 3  Software Quality Assurance, Quality Assurance,...
# 4  Marketing Strategy, Jewelry Design, E-commerce...
#
#                        skill1 endorsement1             skill2 endorsement2  \
# 0          Strategic Planning           31         Leadership           26
# 1                  Web Design           99          Marketing           66
# 2                     Editing           39           Blogging           31
# 3  Software Quality Assurance           71  Quality Assurance           69
# 4          Marketing Strategy           20     Jewelry Design           18
#
#                skill3 endorsement3              skill4 endorsement4  \
# 0  Marketing Strategy           24            Strategy           21
# 1   Business Strategy           11                 SEO           47
# 2        Social Media           25      Event Planning           14
# 3             Testing           66      System Testing           44
# 4          E-commerce           17  Online Advertising           15
#
#                      skill5 endorsement5                  skill6 endorsement6  \
# 0  New Business Development           18       Business Strategy           15
# 1           Web Development           40        Online Marketing           32
# 2                       SEO           11  Curriculum Development            8
# 3         Usability Testing           42               Start-ups           35
# 4          Entrepreneurship           13                   Sales           10
#
#                                              baseUrl              profileId  \
# 0    https://www.linkedin.com/in/mark-kohoot-96a08b1    mark-kohoot-96a08b1
# 1            https://www.linkedin.com/in/jonbowerman            jonbowerman
# 2           https://www.linkedin.com/in/parkeralynch           parkeralynch
# 3          https://www.linkedin.com/in/shacharschiff          shacharschiff
# 4  https://www.linkedin.com/in/gary-lacourt-811b1874  gary-lacourt-811b1874
#
#                   timestamp          jobLocation2
# 0  2022-01-03T20:00:58.586Z                   NaN
# 1  2022-01-03T20:01:43.218Z   West Bloomfield, MI
# 2  2022-01-03T20:02:59.669Z  Greater Detroit Area
# 3  2022-01-03T20:03:52.557Z                   NaN
# 4  2022-01-03T20:04:29.760Z                   NaN

# %% [markdown]
# We leave only the most interesting data for analysis, which potentially carry important user characteristics.

# %%
selected_columns = ['profileId', 'Result', 'Other', 
       'headline', 'location', 'subscribers', 'company', 'jobTitle',
       'jobLocation', 'jobDateRange', 'school', 'school2', 
       'allSkills']

linkedin_data = linkedin_data[selected_columns]

linkedin_data.describe(include='object')
# Out:
#                     profileId       Result   Other                headline  \
# count                     348          348     191                     347
# unique                    346            6       4                     344
# top     bill-cochrane-7495667  2021 Member  Hunter  Co-Founder at Foothold
# freq                        2          157     142                       2
#
#                             location   company jobTitle    jobLocation  \
# count                            348       346      347            215
# unique                           205       342      203            152
# top     Austin, Texas, United States  Foothold  Founder  United States
# freq                              14         2       39             14
#
#                 jobDateRange                     school  \
# count                    342                        328
# unique                   189                        269
# top     Jan 2020 â€“ Present  The Ohio State University
# freq                      10                          7
#
#                                 school2  \
# count                               208
# unique                              200
# top     University of Wisconsin-Madison
# freq                                  3
#
#                                                 allSkills
# count                                                 330
# unique                                                328
# top     Nonprofit Management, Program Management, Proj...
# freq                                                    2

# %% [markdown]
# Checking for duplicates again.

# %%
# check data for duplicates
linkedin_data = linkedin_data.drop_duplicates()
len(linkedin_data)
# Out:
# 346

# %% [markdown]
# Two lines with duplicates have been deleted.
# Let's take a look at the new, cleaned up dataset.

# %%
linkedin_data.head()
# Out:
#                profileId                   Result   Other  \
# 0    mark-kohoot-96a08b1  5. Purchased Membership  Hunter
# 1            jonbowerman  5. Purchased Membership  Hunter
# 2           parkeralynch  5. Purchased Membership  Hunter
# 3          shacharschiff  5. Purchased Membership  Hunter
# 4  gary-lacourt-811b1874        4.Purchased Event  Hunter
#
#                                             headline  \
# 0          Bio-pharmaceutical / functional fragrance
# 1  Co Founder and CTO - Product Development and M...
# 2  CEO at HedgeHog Health | 2020-2021 Global Educ...
# 3  I believe that high-quality, powerful software...
# 4                 Founder and CEO, Forever Companies
#
#                               location  subscribers  \
# 0       Cleveland, Ohio, United States       1704.0
# 1  Farmington, Michigan, United States       1745.0
# 2   Royal Oak, Michigan, United States       2549.0
# 3          Dallas-Fort Worth Metroplex       1696.0
# 4  Milwaukee, Wisconsin, United States        710.0
#
#                                       company                   jobTitle  \
# 0                                   Aeroscena                        CEO
# 1                               Kids Draw Bob  President and Illustrator
# 2                             HedgeHog Health    Chief Executive Officer
# 3  BadTestingÂ® â€” Better Software. On Time.      Founder and Principal
# 4                           Forever Companies              Founder & CEO
#
#                     jobLocation          jobDateRange  \
# 0    Cleveland/Akron, Ohio Area  Sep 2010 â€“ Present
# 1          Bloomfield Hills, MI  Jul 2019 â€“ Present
# 2                           NaN  Nov 2019 â€“ Present
# 3  Austin, Texas, United States  Mar 2012 â€“ Present
# 4        Greater Milwaukee Area  Aug 2004 â€“ Present
#
#                                 school                            school2  \
# 0  Audencia Nantes Ecole de Management          The Ohio State University
# 1               University of Michigan    Walled Lake Central High School
# 2                  New York University     Indiana University Bloomington
# 3                     DeVry University                                NaN
# 4              Northwestern University  University of Wisconsin-Milwaukee
#
#                                            allSkills
# 0  Strategic Planning, Leadership, Marketing Stra...
# 1  Web Design, Marketing, Business Strategy, SEO,...
# 2  Editing, Blogging, Social Media, Event Plannin...
# 3  Software Quality Assurance, Quality Assurance,...
# 4  Marketing Strategy, Jewelry Design, E-commerce...

# %% [markdown]
# Let's perform some more small manipulations with the dataset. For convenience, we will slightly change the data in a couple of columns and put the categories in order.

# %%
# cleaning and standardizing job titles and skills
# convert the values in the 'jobTitle' column to lower case using .loc
linkedin_data['job_title'] = linkedin_data['jobTitle'].str.lower().str.strip()

# turn skills into lists
linkedin_data['skills_list'] = linkedin_data['allSkills'].str.lower().str.split(',')

# get rid of the old columns that we just replaced
linkedin_data = linkedin_data.drop(columns=['jobTitle', 'allSkills'])

# simplifying the Result column for easier analysis
# mapping the Result to a simpler form
result_mapping = {
    '5. Purchased Membership': 'Purchased Membership',
    '4.Purchased Event': 'Purchased Event',
    '3. Approved': 'Approved',
    '2. Sent Personal f/u': 'Sent Follow-up',
    'Out of Sequence': 'Out of Sequence',
    '2021 Member': '2021 Member'
}
linkedin_data['Result'] = linkedin_data['Result'].map(result_mapping)

# extracting and standardizing location
linkedin_data['location_standard'] = linkedin_data['location'].str.split(',').str[0].str.strip()

# %% [markdown]
# Notice that the locations are listed in different forms. Not everywhere the country is specified, or not everywhere it is the USA. Let's find out the number of such lines.

# %%
# select rows that do not contain the string 'United States' in the 'Country' column
not_from_us = linkedin_data[~linkedin_data['location'].str.contains('United States')]

print(f'Not from the US: {len(not_from_us) / len(linkedin_data) * 100: .1f}%')
# Out:
# Not from the US:  26.0%

# %% [markdown]
# In this section, we removed columns with a lot of omissions from the dataset, replaced and tidied up some columns. We found out that 26% of locations do not contain the country or it is not the United States.

# %% [markdown]
# ### Feature Analysis
#
# Now let's move on to explore the differences between target users and everyone else in more detail. Let's find the share of users who performed a target action: **Purchased Membership** or **Purchased Event**.

# %%
print(f"% Purchased Membership: {len(linkedin_data[linkedin_data['Result'] == 'Purchased Membership']) * 100 / len(linkedin_data) : .1f}%")
print(f"% Purchased Event: {len(linkedin_data[linkedin_data['Result'] == 'Purchased Event']) * 100 / len(linkedin_data) : .1f}%")
# Out:
# % Purchased Membership:  1.2%
# % Purchased Event:  1.7%

# %% [markdown]
# Let's study the overall distribution of users by parameters such as occupation and location. Let's display only the top 10 for each of the parameters.

# %%
# setting plot style
sns.set(style="whitegrid")

# analyzing the distribution of outcomes across different job titles
top_job_titles = linkedin_data['job_title'].value_counts().head(10).index
data_top_job_titles = linkedin_data[linkedin_data['job_title'].isin(top_job_titles)]

plt.figure(figsize=(12, 6))
sns.countplot(data=data_top_job_titles, y='job_title', hue='Result')
plt.title('Distribution of Outcomes by Job Titles')
plt.xlabel('Count')
plt.ylabel('Job Title')
plt.show()

# analyzing the distribution of outcomes across different locations
top_locations = linkedin_data['location_standard'].value_counts().head(10).index
data_top_locations = linkedin_data[linkedin_data['location_standard'].isin(top_locations)]

plt.figure(figsize=(12, 6))
sns.countplot(data=data_top_locations, y='location_standard', hue='Result')
plt.title('Distribution of Outcomes by Locations')
plt.xlabel('Count')
plt.ylabel('Location')
plt.show()

# %% [markdown]
# Among all users, ceo's and founders have the highest number of users. Austin and Millwaukee stand out in terms of location, although the number of users from each city is not as large relative to the total. Targeted users do not stand out among the rest.

# %% [markdown]
# ### Feature Engineering
# For ease of analysis, let's reduce the number of user groups by target action to two. The `"Best leads"` category includes users who purchased Event or Membership. All others will be categorized as `"Others"`.
# Extract meaningful features from the existing data (e.g., categorize job titles, extract skills).

# %%
# define a custom function to merge categories
def combine_categories(result):
    if result == 'Purchased Event' or result == 'Purchased Membership':
        return 'Best leads'
    else:
        return 'Others'

# %%
# apply a custom function to the 'Result' column using the apply() method
linkedin_data['leads_category'] = linkedin_data['Result'].apply(combine_categories)

# %% [markdown]
# Since some similarity in the job titles could be seen in the chart in the previous section, we can combine the closest in meaning (ceo, founder, chief executive officer) into the top 10 names of the category.

# %%
def categorize_occupation(job):
    if isinstance(job, str) and ('ceo' in job or 'founder' in job or 'chief executive officer' in job):
        return 'ceo, founder'
    else:
        return job

linkedin_data['job_title_new'] = linkedin_data['job_title'].apply(categorize_occupation)

# %% [markdown]
# Let's reconstruct the distribution of job titles by consolidated categories.

# %%
# setting plot style
sns.set(style="whitegrid")

# analyzing the distribution of outcomes across different job titles
top_job_titles = linkedin_data['job_title_new'].value_counts().head(10).index
data_top_job_titles = linkedin_data[linkedin_data['job_title_new'].isin(top_job_titles)]

plt.figure(figsize=(12, 6))
sns.countplot(data=data_top_job_titles, y='job_title_new', hue='leads_category')
plt.title('Distribution of Outcomes by Job Titles')
plt.xlabel('Count')
plt.ylabel('Job Title')
plt.show()

# %% [markdown]
# So among the users in the dataset, ceo and founders are definitely leading the way, as well as the target group.
# Now let's assess the locations.

# %%
# analyzing the distribution of outcomes across different locations
top_locations = linkedin_data['location_standard'].value_counts().head(10).index
data_top_locations = linkedin_data[linkedin_data['location_standard'].isin(top_locations)]

plt.figure(figsize=(12, 6))
sns.countplot(data=data_top_locations, y='location_standard', hue='leads_category')
plt.title('Distribution of Outcomes by Locations')
plt.xlabel('Count')
plt.ylabel('Location')
plt.show()

# %% [markdown]
# There is some variation, but overall too few users in each city to speak of any meaningful difference between users. Let's just look at the locations of the target users in the table.

# %%
# separate the target users into one table
bl_companies = linkedin_data[linkedin_data['leads_category'] == 'Best leads']
bl_companies[['profileId', 'location']].T
# Out:
#                                         0  \
# profileId             mark-kohoot-96a08b1
# location   Cleveland, Ohio, United States
#
#                                              1  \
# profileId                          jonbowerman
# location   Farmington, Michigan, United States
#
#                                             2                            3  \
# profileId                        parkeralynch                shacharschiff
# location   Royal Oak, Michigan, United States  Dallas-Fort Worth Metroplex
#
#                                              4  \
# profileId                gary-lacourt-811b1874
# location   Milwaukee, Wisconsin, United States
#
#                                              5  \
# profileId                lyle-stoflet-38a07ab8
# location   Milwaukee, Wisconsin, United States
#
#                                           6  \
# profileId                     whiteandrewdc
# location   Holland, Michigan, United States
#
#                                                7  \
# profileId                           donniemcfall
# location   Minneapolis, Minnesota, United States
#
#                                        8                          9
# profileId                        sykraft          alan-dahl-2a6781b
# location   Los Angeles Metropolitan Area  Atlanta Metropolitan Area

# %% [markdown]
# Two are from Milwaukee, the rest are from different towns. Let's look at the number of subscribers of our users.

# %%
sns.histplot(data=linkedin_data, x='subscribers', hue='leads_category', element='bars', stat='count')
plt.title('Distribution by Subscribers');

# %% [markdown]
# Targeted users don't stand out from the rest. They generally do not have more than 2500 subscribers.  Let's study the distribution of users by companies.

# %%
# analyzing the distribution of outcomes across different companies
top_companies = linkedin_data['company'].value_counts().head(10).index
data_top_companies = linkedin_data[linkedin_data['company'].isin(top_companies)]

plt.figure(figsize=(12, 6))
sns.countplot(data=data_top_companies, y='company', hue='leads_category')
plt.title('Distribution of Outcomes by Company')
plt.xlabel('Count')
plt.ylabel('Company')
plt.show()

# %% [markdown]
# We'll also look separately at where the target users are working.

# %%
# check only companies
bl_companies[['profileId', 'company']].T
# Out:
#                              0              1                2  \
# profileId  mark-kohoot-96a08b1    jonbowerman     parkeralynch
# company              Aeroscena  Kids Draw Bob  HedgeHog Health
#
#                                                     3                      4  \
# profileId                               shacharschiff  gary-lacourt-811b1874
# company    BadTestingÂ® â€” Better Software. On Time.      Forever Companies
#
#                                                          5              6  \
# profileId                            lyle-stoflet-38a07ab8  whiteandrewdc
# company    Stratus Industries / Gear Grove / Containers Up    Align & Co.
#
#                                 7                 8                  9
# profileId            donniemcfall           sykraft  alan-dahl-2a6781b
# company    McFall Consulting Inc.  Fantastic Brands        BootsUp Co.

# %% [markdown]
# Again no correlation, all from different companies. Let's look at the schools where the users were trained.

# %%
# analyzing the distribution of outcomes across different locations
top_schools = linkedin_data['school'].value_counts().head(10).index
data_top_schools = linkedin_data[linkedin_data['school'].isin(top_schools)]

plt.figure(figsize=(12, 6))
sns.countplot(data=data_top_schools, y='school', hue='leads_category')
plt.title('Distribution of Outcomes by School')
plt.xlabel('Count')
plt.ylabel('School')
plt.show()

# %%
# check only schools
bl_companies[['profileId', 'school']].T
# Out:
#                                              0                       1  \
# profileId                  mark-kohoot-96a08b1             jonbowerman
# school     Audencia Nantes Ecole de Management  University of Michigan
#
#                              2                 3                        4  \
# profileId         parkeralynch     shacharschiff    gary-lacourt-811b1874
# school     New York University  DeVry University  Northwestern University
#
#                                            5                               6  \
# profileId              lyle-stoflet-38a07ab8                   whiteandrewdc
# school     Waukesha County Technical College  Palmer College of Chiropractic
#
#                                                            7  \
# profileId                                       donniemcfall
# school     University of Minnesota - Carlson School of Ma...
#
#                                                 8                          9
# profileId                                 sykraft          alan-dahl-2a6781b
# school     California State University-Northridge  Oklahoma State University

# %% [markdown]
# It's even amazing how different and unique our users are. Finally, let's look at the basic skills. Let's summarize the top 5 skills in each group.

# %%
# setting the style
sns.set(style="whitegrid")

# reset the current index and create a new unique index
linkedin_data.reset_index(drop=True, inplace=True)

# expand the list so that each item in the list is a separate line
linkedin_data_expanded = linkedin_data.explode('skills_list')

# categorize the data
data_others = linkedin_data_expanded[linkedin_data_expanded['leads_category'] == 'Others']
data_best_leads = linkedin_data_expanded[linkedin_data_expanded['leads_category'] == 'Best leads']

# finding the top 5 skills for each category
top_skills_others = data_others['skills_list'].value_counts().head(5)
top_skills_best_leads = data_best_leads['skills_list'].value_counts().head(5)

# creating subplots
fig, axes = plt.subplots(1, 2, figsize=(20, 8))


# horizontal histogram for the 'Others' category
sns.barplot(x=top_skills_others.values, y=top_skills_others.index, ax=axes[0], palette="Blues_d")
axes[0].set_title('Top 5 Skills in Others Category')
axes[0].set_xlabel('Count')
axes[0].set_ylabel('Skills')

# horizontal histogram for the 'Best leads' category
sns.barplot(x=top_skills_best_leads.values, y=top_skills_best_leads.index, ax=axes[1], palette="Greens_d")
axes[1].set_title('Top 5 Skills in Best Leads Category')
axes[1].set_xlabel('Count')
axes[1].set_ylabel('Skills')

plt.tight_layout()
plt.show()

# %% [markdown]
# Here, too, there are no particular differences. Note that for the target group the skill "leadership" is not among the top five most common skills, unlike the other groups.

# %% [markdown]
# ### Final assessment

# %% [markdown]
# A comprehensive analysis of the data provided was conducted. It was obtained that the target group of users is no more than 3% of all studied profiles. In absolute figures it is only 10 users, so the study of their profiles does not allow to make a detailed description of potentially profitable users.
#
# Users who performed one of the target actions (ordered both a ticket and a subscription or only bought a ticket) are mostly ceo or founders by profession. A couple of people are also categorized as owner and managing partner. All target users are from America, but from different cities. So it is also impossible to identify any correlation here.
#
# Distribution of users by number of subscribers showed that target users do not stand out by this criterion in any way - they (with a single exception) do not have more than 2500 subscribers.
# All users are from different companies, including target users.The same can be said about schools. Analysis of the top 5 skills for the target group and other users also did not allow us to make a clear distinction between the latter. It can be said that for the target group the skill 'leadership' is not among the top five most common skills, unlike the rest of the group.
#
# Thus, based on the data obtained and the analysis performed, it is almost impossible to separate the target group of users from the rest.Perhaps analysis by machine learning methods (division into trees or clusters) will help here, as it will allow to take into account all attributes in the aggregate.
